# %% [markdown]
#  # Define the Project

# %% [markdown]
# # Predicting whether a credit card transaction is fraudulent or not

# %%
# 1. Import Data
import pandas as pd

# Load your dataset
df = pd.read_csv("creditcard.csv")   
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# #  2. Data Inspection

# %%
print("Shape:", df.shape)
# Out:
# Shape: (284807, 31)

# %%
print("Columns:", df.columns)
# Out:
# Columns: Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
print("Missing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print("Data Types:\n", df.dtypes)
# Out:
# Data Types:
#  Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# # 3. Data Cleaning / Data Preprocessing

# %%
df.drop_duplicates(inplace=True)

# %%
print("Shape:", df.shape)
# Out:
# Shape: (283726, 31)

# %% [markdown]
# # 4. EDA / Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df)
plt.show()

# %%
plt.boxplot(df['Amount'])
plt.show()

# %%
class_counts = df['Class'].value_counts()
class_counts
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
plt.bar(class_counts.index, class_counts.values, color=['green', 'red'])
plt.xticks([0, 1], ['Not Fraud', 'Fraud'])
plt.title("Class Distribution")
plt.ylabel("Number of Transactions")
plt.show()

# %%
# Note: Dataset is highly imbalanced
# 0 → Not Fraud (~2 lakh), 1 → Fraud (~400)
# If we directly train our model on this dataset, 
# it will always predict 'Not Fraud' because the data is highly imbalanced. 
# Even if the model shows 99% accuracy, it will still be a useless model — that's why we balanced the dataset.

# %%
fraud = df[df['Class'] == 1]
not_fraud = df[df['Class'] == 0]

# %%
not_fraud_sampled = not_fraud.sample(n=len(fraud)*4, random_state=42)

# %%
counts = [len(not_fraud_sampled), len(fraud)]
labels = ['Not Fraud', 'Fraud']

plt.bar(labels, counts, color=['green', 'red'])
plt.title("Class Distribution")
plt.ylabel("Number of Transactions")
plt.show()

# %%
# adding the dataset
df_balanced = pd.concat([fraud, not_fraud_sampled])

# %%
df_balanced = df_balanced.sample(frac=1, random_state=42)

# %%
# Correlation matrix on balanced dataset
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = df_balanced.corr()

# %%
# Plot the heatmap
plt.figure(figsize=(18, 12))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix (Balanced Dataset)", fontsize=16)
plt.show()

# %% [markdown]
# # Splitting the dataset

# %%
X = df_balanced.drop('Class', axis=1)
y = df_balanced['Class']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # Using svm model

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

svm = SVC(kernel='rbf', class_weight='balanced')  # 'balanced' handles class imbalance
svm.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced')

# %%
# Predict
y_pred = svm.predict(X_test)
# Use the original test features (X_test), and test labels (y_test)
print("Accuracy Score:", svm.score(X_test, y_test))

# Evaluate
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy Score: 0.9577167019027484
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       378
#            1       0.91      0.87      0.89        95
#
#     accuracy                           0.96       473
#    macro avg       0.94      0.93      0.93       473
# weighted avg       0.96      0.96      0.96       473
#
# [[370   8]
#  [ 12  83]]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
y_pred = logreg.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# ROC AUC score
roc = roc_auc_score(y_test, y_pred)
print("ROC AUC Score:", roc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       378
#            1       0.94      0.88      0.91        95
#
#     accuracy                           0.97       473
#    macro avg       0.96      0.94      0.95       473
# weighted avg       0.97      0.97      0.97       473
#
# Confusion Matrix:
# [[373   5]
#  [ 11  84]]
# ROC AUC Score: 0.935491506544138

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred = rf.predict(X_test)
y_pred_proba = rf.predict_proba(X_test)[:, 1]

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# ROC AUC Score
roc = roc_auc_score(y_test, y_pred_proba)
print("ROC AUC Score:", roc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       378
#            1       0.99      0.86      0.92        95
#
#     accuracy                           0.97       473
#    macro avg       0.98      0.93      0.95       473
# weighted avg       0.97      0.97      0.97       473
#
# Confusion Matrix:
#  [[377   1]
#  [ 13  82]]
# ROC AUC Score: 0.9769980506822612

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest Confusion Matrix")
plt.show()

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# %%
xgboostModel = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    scale_pos_weight=len(not_fraud)/len(fraud),  # balance fraud class
    random_state=42
)

xgboostModel.fit(X_train, y_train)
# Out:
# E:\machinelearning\Lib\site-packages\xgboost\training.py:183: UserWarning: [10:37:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
y_pred = xgboostModel.predict(X_test)
y_pred_proba = xgboostModel.predict_proba(X_test)[:, 1]

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# ROC AUC Score
roc = roc_auc_score(y_test, y_pred_proba)
print("ROC AUC Score:", roc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       378
#            1       0.91      0.88      0.90        95
#
#     accuracy                           0.96       473
#    macro avg       0.94      0.93      0.94       473
# weighted avg       0.96      0.96      0.96       473
#
# Confusion Matrix:
#  [[370   8]
#  [ 11  84]]
# ROC AUC Score: 0.9756613756613757

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("XGBoost Confusion Matrix")
plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(weights='distance', n_neighbors=5)   
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
y_pred = knn.predict(X_test)
y_pred_proba = knn.predict_proba(X_test)[:, 1]

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# ROC AUC Score
roc = roc_auc_score(y_test, y_pred_proba)
print("ROC AUC Score:", roc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       378
#            1       0.99      0.82      0.90        95
#
#     accuracy                           0.96       473
#    macro avg       0.97      0.91      0.94       473
# weighted avg       0.96      0.96      0.96       473
#
# Confusion Matrix:
#  [[377   1]
#  [ 17  78]]
# ROC AUC Score: 0.9412976886661097

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("KNN Confusion Matrix")
plt.show()

# %% [markdown]
# # Naives bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test)
y_pred_proba = nb.predict_proba(X_test)[:, 1]

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# ROC AUC Score
roc = roc_auc_score(y_test, y_pred_proba)
print("ROC AUC Score:", roc)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       378
#            1       0.95      0.86      0.91        95
#
#     accuracy                           0.96       473
#    macro avg       0.96      0.93      0.94       473
# weighted avg       0.96      0.96      0.96       473
#
# Confusion Matrix:
#  [[374   4]
#  [ 13  82]]
# ROC AUC Score: 0.9503480924533556

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Naive Confusion Matrix")
plt.show()

# %% [markdown]
# # neural network

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(learning_rate='invscaling',hidden_layer_sizes=(150, 50), max_iter=100, random_state=42)
mlp.fit(X_resampled, y_resampled)
# Out:
# MLPClassifier(hidden_layer_sizes=(150, 50), learning_rate='invscaling',
#               max_iter=100, random_state=42)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

y_pred = mlp.predict(X_test)
y_proba = mlp.predict_proba(X_test)[:, 1]

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba))
# Out:
# [[372   6]
#  [ 14  81]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       378
#            1       0.93      0.85      0.89        95
#
#     accuracy                           0.96       473
#    macro avg       0.95      0.92      0.93       473
# weighted avg       0.96      0.96      0.96       473
#
# ROC AUC Score: 0.9631021999443051

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Not Fraud', 'Fraud'],
            yticklabels=['Not Fraud', 'Fraud'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Neural Network Confusion Matrix")
plt.show()

# %% [markdown]
# # Highest accuracy Model ?

# %%
import joblib

# Save model
joblib.dump(xgboostModel, "xgboost_fraud_model.pkl")
# Out:
# ['xgboost_fraud_model.pkl']
